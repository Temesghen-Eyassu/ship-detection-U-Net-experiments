# %% [markdown]
# # Experiment 3: Enhanced Data Augmentation for Robust Ship Detection
# ## Objective
#
# ### The objective of this experiment is to improve the generalization ability of the U-Net model by introducing strong and diverse data augmentation techniques.
#
# ### Unlike Experiment 1 (baseline) and Experiment 2 (basic augmentation), this experiment focuses on:
#
# * Simulating real-world SAR variations
# * Making the model robust to:
#     * Noise
#     * Rotation
#     * Scale changes
#     * Intensity variations
# * Reducing overfitting
# * Improving Dice and IoU performance on validation data

# %% [markdown]
# # 1. Libraries & Dependencies
#
# #### This section imports all required libraries for:
# * Deep learning (PyTorch)
# * Data handling
# * Image processing
# * Augmentation
# * Visualization

# %%
# 1. Libraries & Dependencies


import os
import glob
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import numpy as np
import rasterio

import albumentations as A

import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Configuration
#
# #### Defines:
# * Dataset paths
# * Training parameters
# * Device (GPU/CPU)
# * Output directory

# %%
# 2. Configuration


config = {
    "data": {
        "root": "/dss/dsshome1/0F/di54cak/geo-oma-24/temesghen_ship_detection_notebook/data/Patches",
        "img_dir": "images",
        "mask_dir": "masks",
        "batch_size": 8,
        "num_workers": 2,
        "val_split": 0.2,
    },
    "training": {
        "epochs": 50,
        "lr": 1e-3,
        "device": "cuda" if torch.cuda.is_available() else "cpu",
    },
    "outputs": {
        "save_dir": "outputs"
    }
}

os.makedirs(config["outputs"]["save_dir"], exist_ok=True)

device = config["training"]["device"]
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # 3. Dataset Class
#
# #### Handles:
#
# * Reading SAR images (VV + VH)
# * Clipping & normalization
# * Mask loading
# * Applying augmentations
# * Converting to tensors

# %%
# 3. Dataset Class


class ShipDataset(Dataset):

    def __init__(self, img_paths, mask_paths, transform=None):
        self.img_paths = img_paths
        self.mask_paths = mask_paths
        self.transform = transform

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):

        # Read SAR image
        with rasterio.open(self.img_paths[idx]) as src:

            vv = src.read(1).astype(np.float32)
            vh = src.read(2).astype(np.float32)

            img = np.stack([vv, vh], axis=-1)

            # clipping
            img = np.clip(img, -25, 10)

            # normalization
            img = (img + 25.0) / 35.0

        # Read mask
        with rasterio.open(self.mask_paths[idx]) as src:

            mask = src.read(1).astype(np.float32)

            if mask.max() > 0:
                mask = mask / mask.max()

            mask = np.expand_dims(mask, -1)

        # Augmentation
        if self.transform:

            aug = self.transform(image=img, mask=mask)

            img = aug["image"]
            mask = aug["mask"]

        # Convert to tensor
        img = torch.from_numpy(img).permute(2,0,1).float()
        mask = torch.from_numpy(mask).permute(2,0,1).float()

        return img, mask

# %% [markdown]
# # 4. Data Augmentation (Key Improvement)
#
# #### This is the main contribution of Experiment 3.
# #### Enhancements include:
# * Geometric transformations
# * Noise simulation (important for SAR)
# * Blur (sensor imperfections)
# * Brightness/contrast variations

# %%
# 4. Data Augmentation


train_tf = A.Compose([

    # geometric transformations
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),

    A.Rotate(limit=30, p=0.5),

    A.ShiftScaleRotate(
        shift_limit=0.05,
        scale_limit=0.1,
        rotate_limit=20,
        p=0.5
    ),

    # SAR intensity variations
    A.RandomBrightnessContrast(
        brightness_limit=0.15,
        contrast_limit=0.15,
        p=0.4
    ),

    # simulate SAR noise
    A.GaussNoise(
        var_limit=(5.0,20.0),
        p=0.3
    ),

    # slight blur
    A.GaussianBlur(
        blur_limit=(3,5),
        p=0.2
    )

])
# Out:
# /dss/dsshome1/0F/di54cak/geo-oma-24/.venv/lib64/python3.12/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /dss/dsstbyfs02/scratch/0F/di54cak/di54cak/tmp.T5NVv8pNYM/ipykernel_93957/3948465000.py:27: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(

# %% [markdown]
# # 5. Dataloaders
#
# #### Splits dataset into train/validation
# #### Applies augmentation only to training data

# %%
# 5. Dataloaders

def get_dataloaders(cfg):

    img_dir = os.path.join(cfg["data"]["root"], cfg["data"]["img_dir"])
    mask_dir = os.path.join(cfg["data"]["root"], cfg["data"]["mask_dir"])

    imgs = sorted(glob.glob(os.path.join(img_dir, "*.tif")))
    masks = sorted(glob.glob(os.path.join(mask_dir, "*.tif")))

    split = int((1 - cfg["data"]["val_split"]) * len(imgs))

    train_imgs = imgs[:split]
    val_imgs = imgs[split:]

    train_masks = masks[:split]
    val_masks = masks[split:]

    train_ds = ShipDataset(train_imgs, train_masks, train_tf)
    val_ds = ShipDataset(val_imgs, val_masks, None)

    train_loader = DataLoader(
        train_ds,
        batch_size=cfg["data"]["batch_size"],
        shuffle=True
    )

    val_loader = DataLoader(
        val_ds,
        batch_size=cfg["data"]["batch_size"],
        shuffle=False
    )

    return train_loader, val_loader


train_loader, val_loader = get_dataloaders(config)

print("Train batches:", len(train_loader))
print("Val batches:", len(val_loader))
# Out:
# Train batches: 50
# Val batches: 13

# %% [markdown]
# # 6. U-Net Model
#
# #### Standard U-Net architecture for segmentation:
#
# * Encoder–decoder structure
# * Skip connections
# * Binary mask output

# %%
# 6. U-Net Model


class DoubleConv(nn.Module):

    def __init__(self, in_c, out_c):

        super().__init__()

        self.net = nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),

            nn.Conv2d(out_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.net(x)


class UNet(nn.Module):

    def __init__(self, in_channels=2, base=32):

        super().__init__()

        self.enc1 = DoubleConv(in_channels, base)
        self.enc2 = DoubleConv(base, base*2)
        self.enc3 = DoubleConv(base*2, base*4)

        self.pool = nn.MaxPool2d(2)

        self.bottleneck = DoubleConv(base*4, base*8)

        self.up1 = nn.ConvTranspose2d(base*8, base*4, 2,2)
        self.dec1 = DoubleConv(base*8, base*4)

        self.up2 = nn.ConvTranspose2d(base*4, base*2, 2,2)
        self.dec2 = DoubleConv(base*4, base*2)

        self.up3 = nn.ConvTranspose2d(base*2, base, 2,2)
        self.dec3 = DoubleConv(base*2, base)

        self.out = nn.Conv2d(base,1,1)

    def forward(self, x):

        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))

        b = self.bottleneck(self.pool(e3))

        u1 = self.up1(b)
        d1 = self.dec1(torch.cat([u1,e3], dim=1))

        u2 = self.up2(d1)
        d2 = self.dec2(torch.cat([u2,e2], dim=1))

        u3 = self.up3(d2)
        d3 = self.dec3(torch.cat([u3,e1], dim=1))

        return torch.sigmoid(self.out(d3))


model = UNet(in_channels=2).to(device)

# %% [markdown]
# # 7. Loss & Metrics
#
# #### Used to evaluate segmentation performance:
#
# * BCE Loss for pixel-wise error
# * Dice for overlap quality
# * IoU for region similarity

# %%
# 7. Loss & Metrics


bce = nn.BCELoss()

def dice_coef(pred, target, smooth=1e-6):

    pred = (pred > 0.5).float()

    inter = (pred * target).sum()

    return (2*inter + smooth) / (pred.sum() + target.sum() + smooth)


def iou_score(pred, target, smooth=1e-6):

    pred = (pred > 0.5).float()

    inter = (pred * target).sum()

    union = pred.sum() + target.sum() - inter

    return (inter + smooth) / (union + smooth)

# %% [markdown]
# # 8. Training Loop
#
# #### Performs forward + backward pass
# #### Tracks metrics
# #### Evaluates on validation set

# %%
# 8. Training Loop


optimizer = optim.Adam(model.parameters(), lr=config["training"]["lr"])

train_loss_hist = []
val_loss_hist = []

train_dice_hist = []
val_dice_hist = []

train_iou_hist = []
val_iou_hist = []

for epoch in range(config["training"]["epochs"]):

    model.train()

    tl, td, ti = 0,0,0

    for img, mask in train_loader:

        img = img.to(device)
        mask = mask.to(device)

        pred = model(img)

        loss = bce(pred, mask)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        tl += loss.item()
        td += dice_coef(pred, mask).item()
        ti += iou_score(pred, mask).item()

    model.eval()

    vl, vd, vi = 0,0,0

    with torch.no_grad():

        for img, mask in val_loader:

            img = img.to(device)
            mask = mask.to(device)

            pred = model(img)

            loss = bce(pred, mask)

            vl += loss.item()
            vd += dice_coef(pred, mask).item()
            vi += iou_score(pred, mask).item()

    train_loss_hist.append(tl/len(train_loader))
    val_loss_hist.append(vl/len(val_loader))

    train_dice_hist.append(td/len(train_loader))
    val_dice_hist.append(vd/len(val_loader))

    train_iou_hist.append(ti/len(train_loader))
    val_iou_hist.append(vi/len(val_loader))

    print(f"Epoch {epoch+1}: "
          f"Train Loss={train_loss_hist[-1]:.4f}, "
          f"Val Loss={val_loss_hist[-1]:.4f}, "
          f"Train Dice={train_dice_hist[-1]:.4f}, "
          f"Val Dice={val_dice_hist[-1]:.4f}, "
          f"Train IoU={train_iou_hist[-1]:.4f}, "
          f"Val IoU={val_iou_hist[-1]:.4f}")
# Out:
# Epoch 1: Train Loss=0.3673, Val Loss=0.2112, Train Dice=0.1235, Val Dice=0.0000, Train IoU=0.0710, Val IoU=0.0000
# Epoch 2: Train Loss=0.1944, Val Loss=0.1509, Train Dice=0.0151, Val Dice=0.2023, Train IoU=0.0082, Val IoU=0.1142
# Epoch 3: Train Loss=0.1239, Val Loss=0.0926, Train Dice=0.0110, Val Dice=0.0000, Train IoU=0.0058, Val IoU=0.0000
# Epoch 4: Train Loss=0.0892, Val Loss=0.0620, Train Dice=0.0001, Val Dice=0.0004, Train IoU=0.0001, Val IoU=0.0002
# Epoch 5: Train Loss=0.0716, Val Loss=0.0562, Train Dice=0.0031, Val Dice=0.0000, Train IoU=0.0016, Val IoU=0.0000
# Epoch 6: Train Loss=0.0617, Val Loss=0.0407, Train Dice=0.0049, Val Dice=0.1504, Train IoU=0.0025, Val IoU=0.0820
# Epoch 7: Train Loss=0.0560, Val Loss=0.0497, Train Dice=0.0217, Val Dice=0.0052, Train IoU=0.0117, Val IoU=0.0027
# Epoch 8: Train Loss=0.0523, Val Loss=0.0319, Train Dice=0.1337, Val Dice=0.6010, Train IoU=0.0757, Val IoU=0.4398
# Epoch 9: Train Loss=0.0504, Val Loss=0.0280, Train Dice=0.1775, Val Dice=0.6319, Train IoU=0.1032, Val IoU=0.4729
# Epoch 10: Train Loss=0.0505, Val Loss=0.0308, Train Dice=0.1480, Val Dice=0.4934, Train IoU=0.0856, Val IoU=0.3319
# Epoch 11: Train Loss=0.0478, Val Loss=0.0232, Train Dice=0.2213, Val Dice=0.7367, Train IoU=0.1327, Val IoU=0.5945
# Epoch 12: Train Loss=0.0473, Val Loss=0.0266, Train Dice=0.2324, Val Dice=0.7122, Train IoU=0.1455, Val IoU=0.5628
# Epoch 13: Train Loss=0.0467, Val Loss=0.0261, Train Dice=0.2560, Val Dice=0.5943, Train IoU=0.1569, Val IoU=0.4286
# Epoch 14: Train Loss=0.0460, Val Loss=0.0237, Train Dice=0.2415, Val Dice=0.7091, Train IoU=0.1448, Val IoU=0.5632
# Epoch 15: Train Loss=0.0470, Val Loss=0.0207, Train Dice=0.2424, Val Dice=0.7566, Train IoU=0.1463, Val IoU=0.6164
# Epoch 16: Train Loss=0.0470, Val Loss=0.0277, Train Dice=0.2204, Val Dice=0.5242, Train IoU=0.1320, Val IoU=0.3605
# Epoch 17: Train Loss=0.0460, Val Loss=0.0233, Train Dice=0.2710, Val Dice=0.7331, Train IoU=0.1656, Val IoU=0.5907
# Epoch 18: Train Loss=0.0462, Val Loss=0.0235, Train Dice=0.2571, Val Dice=0.6122, Train IoU=0.1540, Val IoU=0.4482
# Epoch 19: Train Loss=0.0469, Val Loss=0.0438, Train Dice=0.2520, Val Dice=0.0149, Train IoU=0.1538, Val IoU=0.0076
# Epoch 20: Train Loss=0.0455, Val Loss=0.0213, Train Dice=0.2530, Val Dice=0.6948, Train IoU=0.1528, Val IoU=0.5452
# Epoch 21: Train Loss=0.0450, Val Loss=0.0206, Train Dice=0.2850, Val Dice=0.7449, Train IoU=0.1755, Val IoU=0.6067
# Epoch 22: Train Loss=0.0460, Val Loss=0.0249, Train Dice=0.2587, Val Dice=0.4622, Train IoU=0.1581, Val IoU=0.3062
# Epoch 23: Train Loss=0.0442, Val Loss=0.0199, Train Dice=0.2862, Val Dice=0.6776, Train IoU=0.1759, Val IoU=0.5255
# Epoch 24: Train Loss=0.0451, Val Loss=0.0222, Train Dice=0.2564, Val Dice=0.6784, Train IoU=0.1588, Val IoU=0.5257
# Epoch 25: Train Loss=0.0447, Val Loss=0.0269, Train Dice=0.2907, Val Dice=0.3261, Train IoU=0.1801, Val IoU=0.2015
# Epoch 26: Train Loss=0.0458, Val Loss=0.0249, Train Dice=0.2774, Val Dice=0.2169, Train IoU=0.1686, Val IoU=0.1276
# Epoch 27: Train Loss=0.0453, Val Loss=0.0219, Train Dice=0.2586, Val Dice=0.7418, Train IoU=0.1602, Val IoU=0.6014
# Epoch 28: Train Loss=0.0453, Val Loss=0.0196, Train Dice=0.2752, Val Dice=0.7425, Train IoU=0.1685, Val IoU=0.6021
# Epoch 29: Train Loss=0.0450, Val Loss=0.0210, Train Dice=0.2728, Val Dice=0.6904, Train IoU=0.1669, Val IoU=0.5416
# Epoch 30: Train Loss=0.0450, Val Loss=0.0228, Train Dice=0.2926, Val Dice=0.6563, Train IoU=0.1811, Val IoU=0.5011
# Epoch 31: Train Loss=0.0441, Val Loss=0.0190, Train Dice=0.3030, Val Dice=0.7475, Train IoU=0.1898, Val IoU=0.6039
# Epoch 32: Train Loss=0.0448, Val Loss=0.0211, Train Dice=0.2915, Val Dice=0.7410, Train IoU=0.1786, Val IoU=0.5989
# Epoch 33: Train Loss=0.0442, Val Loss=0.0198, Train Dice=0.3055, Val Dice=0.7392, Train IoU=0.1863, Val IoU=0.5964
# Epoch 34: Train Loss=0.0441, Val Loss=0.0217, Train Dice=0.2989, Val Dice=0.6927, Train IoU=0.1848, Val IoU=0.5425
# Epoch 35: Train Loss=0.0455, Val Loss=0.0196, Train Dice=0.2846, Val Dice=0.7425, Train IoU=0.1747, Val IoU=0.6026
# Epoch 36: Train Loss=0.0439, Val Loss=0.0261, Train Dice=0.2990, Val Dice=0.5385, Train IoU=0.1852, Val IoU=0.3780
# Epoch 37: Train Loss=0.0451, Val Loss=0.0209, Train Dice=0.2937, Val Dice=0.6923, Train IoU=0.1821, Val IoU=0.5436
# Epoch 38: Train Loss=0.0441, Val Loss=0.0212, Train Dice=0.2981, Val Dice=0.6925, Train IoU=0.1849, Val IoU=0.5444
# Epoch 39: Train Loss=0.0442, Val Loss=0.0210, Train Dice=0.3004, Val Dice=0.6534, Train IoU=0.1858, Val IoU=0.5026
# Epoch 40: Train Loss=0.0449, Val Loss=0.0353, Train Dice=0.2859, Val Dice=0.0825, Train IoU=0.1781, Val IoU=0.0450
# Epoch 41: Train Loss=0.0451, Val Loss=0.0239, Train Dice=0.2906, Val Dice=0.5946, Train IoU=0.1797, Val IoU=0.4354
# Epoch 42: Train Loss=0.0443, Val Loss=0.0205, Train Dice=0.2963, Val Dice=0.7381, Train IoU=0.1838, Val IoU=0.5981
# Epoch 43: Train Loss=0.0448, Val Loss=0.0199, Train Dice=0.2982, Val Dice=0.7478, Train IoU=0.1840, Val IoU=0.6061
# Epoch 44: Train Loss=0.0440, Val Loss=0.0207, Train Dice=0.3211, Val Dice=0.6436, Train IoU=0.2021, Val IoU=0.4894
# Epoch 45: Train Loss=0.0445, Val Loss=0.0181, Train Dice=0.3054, Val Dice=0.7567, Train IoU=0.1901, Val IoU=0.6185
# Epoch 46: Train Loss=0.0442, Val Loss=0.0219, Train Dice=0.3241, Val Dice=0.6833, Train IoU=0.2026, Val IoU=0.5327
# Epoch 47: Train Loss=0.0445, Val Loss=0.0199, Train Dice=0.3178, Val Dice=0.7433, Train IoU=0.2016, Val IoU=0.6045
# Epoch 48: Train Loss=0.0439, Val Loss=0.0178, Train Dice=0.3170, Val Dice=0.7512, Train IoU=0.1999, Val IoU=0.6111
# Epoch 49: Train Loss=0.0440, Val Loss=0.0188, Train Dice=0.3097, Val Dice=0.7417, Train IoU=0.1929, Val IoU=0.6020
# Epoch 50: Train Loss=0.0435, Val Loss=0.0214, Train Dice=0.3259, Val Dice=0.7112, Train IoU=0.2026, Val IoU=0.5675

# %% [markdown]
# # 9. Training Curves
#
# #### Visualizes:
#
# * Loss convergence
# * Dice improvement
# * IoU improvement
#
# #### Helps detect:
#
# * Overfitting
# * Underfitting

# %%
# 9. Plot Training Curves


plt.figure(figsize=(10,5))
plt.plot(train_loss_hist,label="Train Loss")
plt.plot(val_loss_hist,label="Val Loss")
plt.legend()
plt.grid(True)
plt.title("Loss Curve")
plt.show()


plt.figure(figsize=(10,5))
plt.plot(train_dice_hist,label="Train Dice")
plt.plot(val_dice_hist,label="Val Dice")
plt.legend()
plt.grid(True)
plt.title("Dice Curve")
plt.show()


plt.figure(figsize=(10,5))
plt.plot(train_iou_hist,label="Train IoU")
plt.plot(val_iou_hist,label="Val IoU")
plt.legend()
plt.grid(True)
plt.title("IoU Curve")
plt.show()

# %% [markdown]
# # 10. Prediction Visualization
#
# #### Shows:
# * Input channels (VV, VH)
# * Ground truth mask
# * Predicted mask
#
# #### Useful for qualitative evaluation.

# %%
# 10. Visualize Predictions

img, mask = next(iter(val_loader))

img = img.to(device)
mask = mask.to(device)

with torch.no_grad():

    pred = model(img)

img = img.cpu()
mask = mask.cpu()
pred = pred.cpu()

fig, axs = plt.subplots(1,4, figsize=(15,5))

axs[0].imshow(img[0,0], cmap="gray")
axs[0].set_title("VV")

axs[1].imshow(img[0,1], cmap="gray")
axs[1].set_title("VH")

axs[2].imshow(mask[0,0], cmap="gray")
axs[2].set_title("GT Mask")

axs[3].imshow(pred[0,0], cmap="gray")
axs[3].set_title("Predicted Mask")

for ax in axs:
    ax.axis("off")

plt.tight_layout()
plt.show()
